# %% [markdown]
# * BIDAF includes character-level, word-level, and contextual embeddings,
# and uses bi-directional attention flow to obtain a query-aware context representation of each word

# %% [markdown]
# ![image.png](attachment:image.png)
