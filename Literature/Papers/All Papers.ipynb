# %% [markdown]
# *each tick represents a pass through the paper
#
#
# ### Graph Neural Networks:
# * https://arxiv.org/pdf/1511.05493 Gated Graph Sequence Neural Networks ✔
# * https://arxiv.org/pdf/1609.02907 Semi-Supervised Classification with Graph Convolutional Networks ✔
# * https://arxiv.org/abs/1706.02216 Inductive Representation Learning on Large Graphs (SAGE conv)
# * https://arxiv.org/pdf/1710.10903.pdf Graph Attention Networks
#  * datasets:  Cora, Citeseer and Pubmed citation
#  *
# * https://arxiv.org/pdf/1806.09835 Graph-to-Sequence Learning using Gated Graph Neural Networks
# * https://arxiv.org/pdf/1904.02342.pdf Text Generation from Knowledge Graphs with Graph Transformers ✔
#  * given knowledge graphs a, generates scientific abstracts
#
#
# #### Pooling
# * https://arxiv.org/pdf/1905.10990.pdf Edge Contraction Pooling for Graph Neural Networks
#
# ### Question Answering:
# * https://arxiv.org/pdf/1611.01603.pdf Bi-directional Attention Flow for Machine Comprehension (BiDAF) - a standard approach to question answering ✔
#
# ### Datasets:
# * https://www.aclweb.org/anthology/Q18-1021 Constructing Datasets for Multi-hop Reading Comprehension Across Documents
# * https://arxiv.org/pdf/1809.09600.pdf HOTPOTQA: A Dataset for Diverse, Explainable Multi-hop Question Answering
# * https://arxiv.org/pdf/1907.09190 ELI5: Long Form Question Answering
#
# ### Other papers using relevant graph representations:
# * https://www.aclweb.org/anthology/P19-1598 Barack’s Wife Hillary: Using Knowledge Graphs for Fact-Aware Language Modeling ✔
# * https://arxiv.org/pdf/1909.01066 Language Models as Knowledge Bases?
#
# ### Knowledge graph construction for QA:
# * https://arxiv.org/pdf/1810.05682 Building Dynamic Knowledge Graphs from Text using Machine Reading Comprehension ✔
# * https://arxiv.org/pdf/1911.03876.pdf Dynamic Knowledge Graph Construction for Zero-shot Commonsense Question Answering
# * https://www.aclweb.org/anthology/D19-1428.pdf Using Local Knowledge Graph Construction to Scale Seq2Seq Models to Multi-Document Inputs
#
# ### Models for multi-hop QA:
# * https://arxiv.org/pdf/1804.05922.pdf Neural Models for Reasoning over Multiple Mentions using Coreference
#  * RNN with Coref-GRU (C-GRU) Layer which feeds connects mentions and entities directly
#  * uses Berkeley Entity Resolution system for Corefs (62% F1 score on the CoNLL 2011 test set)
#  * evaluated on BAbi AI tasks, wikihop(61.5), LAMBADA
#
# * https://arxiv.org/pdf/1808.09920 Question Answering by Reasoning Across Documents with Graph Convolutional Networks (Entity-GCN)
#  * nodes are extracted from text for only candidate and query entities.
#  * uses edges: same-doc, same-ent, coref, complement (ITCW none of the previous 3,to fully connect graph)
#  * uses custom gated version of geometric.nn.RGCNConv, ELMO context embeddings/no fine tuning
#  * different
# * https://arxiv.org/pdf/1809.02040.pdf Exploring Graph-structured Passage Representation for Multi-hop Reading Comprehension with Graph Neural Networks
#  * Compares GCN to GRN (forget gates in edges eg GRU)
#  * extracts all context entities as nodes, does not use candidate or query entities
#  * uses same coref and window edges
#  * scores all nodes using an attention-like scoring which is informed by node state and query. nodes representing the same ents are grouped
# * https://www.aclweb.org/anthology/P19-1260.pdf Multi-hop Reading Comprehension across Multiple Documents by Reasoning over Heterogeneous Graphs
#  * Uses same GCN as EGCN
#  * most node types - all context entities, context and query ents + document nodes (passage nodes by my labels)
# * https://arxiv.org/pdf/1906.05210.pdf Explore, Propose, and Assemble: An Interpretable Model for Multi-Hop Reading Comprehension
#
# ### Points of interest:
# * https://arxiv.org/abs/1912.01412 Deep Learning for Symbolic Mathematics
# * https://arxiv.org/abs/1804.00823 Graph2Seq: Graph to Sequence Learning with Attention-based Neural Networks

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Graph neural networks: Variations and applications
# https://www.youtube.com/watch?v=cWIeTMklzNg
