# %% [markdown]
# Datasets: Wikihop (66.4)

# %% [markdown]
# ![Screenshot%20from%202020-05-27%2019-55-04.png](attachment:Screenshot%20from%202020-05-27%2019-55-04.png)

# %% [markdown]
# * we discard mentions which are ambiguously
# resolved to multiple coreference chains; this
# may sacrifice recall, but avoids propagating
# ambiguity.
#
#
# * Query-dependent mention encodings ELMo
# encodings are used to produce a query representation q ∈ R^K as well. Here, q is a concatenation of the final outputs from a bidirectional RNN
# layer trained to re-encode ELMo representations
# of words in the query. Query-dependent mention encodings ˆxi = fx(q, xi) are
# generated by a trainable function fx which is parameterized by a feed-forward neural network
